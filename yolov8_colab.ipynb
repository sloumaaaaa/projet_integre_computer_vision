# %% [markdown]
# <a href="https://colab.research.google.com/github/sloumaaaaa/projet_integre_computer_vision/blob/animal_detection_yolov8/yolov8_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install ultralytics (YOLOv8)
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.7 MB/s eta 0:00:00

# %%
# 2. Mount Google Drive (if your data is on Drive)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 4. Train YOLOv8 on your dataset
from ultralytics import YOLO

# Path to your data.yaml (update if needed)
data_yaml = '/content/drive/MyDrive/Projet_integre_2BA8/data.yaml'

# Start training
model = YOLO('yolov8n.pt')  # You can use yolov8s.pt, yolov8m.pt, etc.
results = model.train(
    data=data_yaml,
    epochs=50,
    imgsz=224,
    project='output',
    name='yolov8_exp',
    exist_ok=True
)
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# 5. Evaluate the trained model
metrics = model.val(data=data_yaml)
print('Evaluation metrics:', metrics)

# %%
# 6. Test on a single image
#test_img = '/content/drive/MyDrive/your_project/test_image.jpg'  # <-- CHANGE THIS
#results = model(test_img)
#results.show()  # Show image with detections
